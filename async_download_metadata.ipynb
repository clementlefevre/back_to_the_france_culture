# %%
import requests
import pandas as pd

from lxml import etree
import time
from random import randint
from aiohttp import ClientSession,TCPConnector
import nest_asyncio
import glob
import asyncio
import numpy as np

# asyncio and jupyter cause trouble, this is a fix :
# https://markhneedham.com/blog/2019/05/10/jupyter-runtimeerror-this-event-loop-is-already-running/
nest_asyncio.apply()

# %%
ROOT_URL = 'https://www.franceculture.fr/emissions/les-chemins-de-la-philosophie?p={}'
range_url = range(1,3)

# %%
async def get_list_of_podscast_on_page(page_number,session):
    url =ROOT_URL.format(str(page_number))
    print(url)
    
    try:
        async with session.get(url) as r:
            content = await r.text()
            e = etree.HTML(content)
            list_dict = []
            elements = e.xpath("//div[@class='teaser-replay-button-wrapper']//button")
            list_dic  = [dict(d.attrib) for d in elements]
            df = pd.DataFrame(list_dic)
            return df
          
    except Exception as e:
        print(e)
        return None

# %%
URL = "https://www.franceculture.fr/emissions/lart-est-la-matiere"
response = requests.get(URL)
e = etree.HTML(response.text())        
elements = e.xpath("//div[@class='teaser-replay-button-wrapper']//button")
def get_podcast_description(content):
    pass
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-9caa8e146d22> in <module>
#       1 URL = "https://www.franceculture.fr/emissions/lart-est-la-matiere"
#       2 response = requests.get(URL)
# ----> 3 e = etree.HTML(response.text())
#       4 elements = e.xpath("//div[@class='teaser-replay-button-wrapper']//button")
#       5 def get_podcast_description(content):
#
# TypeError: 'str' object is not callable

# %%
async def run(range_url):
  
    tasks = []

    # Fetch all responses within one Client session,
    # keep connection alive for all requests.
    # we set the connector to 10 because we are well educated people who play by the rules :
    connector = TCPConnector(limit=10)
    async with ClientSession(connector=connector) as session:
        for url in range_url:
            task = asyncio.ensure_future(get_list_of_podscast_on_page(url, session))
            tasks.append(task)

        responses = await asyncio.gather(*tasks,return_exceptions=True )
        # you now have all response bodies in this variable
        return (responses)
    
def scrap_all_metadata(dt_lista):
    loop = asyncio.get_event_loop()
    future = asyncio.ensure_future(run(range_url))
    df_list = loop.run_until_complete(future) 
    
    return df_list

# %%
dt_lista = scrap_all_metadata(range_url)
dt_lista
# Out:
# https://www.franceculture.fr/emissions/les-chemins-de-la-philosophie?p=1
# https://www.franceculture.fr/emissions/les-chemins-de-la-philosophie?p=2
# [                             class data-btn-type data-network-change  \
#  0   replay-button paused timeshift     timeshift
#  1         replay-button paused aod           aod
#  2         replay-button paused aod           aod
#  3         replay-button paused aod           aod
#  4         replay-button paused aod           aod
#  5         replay-button paused aod           aod
#  6         replay-button paused aod           aod
#  7         replay-button paused aod           aod
#  8         replay-button paused aod           aod
#  9         replay-button paused aod           aod
#  10        replay-button paused aod           aod
#  11        replay-button paused aod           aod
#  12        replay-button paused aod           aod
#  13        replay-button paused aod           aod
#  14        replay-button paused aod           aod
#
#                                                  title  \
#  0   Réécouter Profession philosophe (61/62) : Céli...
#  1   Réécouter Profession philosophe (60/62) : Elsa...
#  2   Réécouter Profession philosophe (59/74) : Tris...
fae969a-3f60-11e5-8314-005056a87c89             savoirs
#  1   2fae969a-3f60-11e5-8314-005056a87c89             savoirs
#  2   2fae969a-3f60-11e5-8314-005056a87c89             savoirs
#  3   2fae969a-3f60-11e5-8314-005056a87c89             savoirs
#  4   2fae969a-3f60-11e5-8314-005056a87c89             savoirs
#  5   2fae969a-3f60-11e5-8314-005056a87c89             savoirs
#  6   2fae969a-3f60-11e5-8314-005056a87c89             savoirs
#  7   2fae969a-3f60-11e5-8314-005056a87c89             savoirs
#  8   2fae969a-3f60-11e5-8314-005056a87c89             savoirs
#  9   2fae969a-3f60-11e5-8314-005056a87c89             savoirs
#  10  2fae969a-3f60-11e5-8314-005056a87c89             savoirs
#  11  2fae969a-3f60-11e5-8314-005056a87c89             savoirs
#  12  2fae969a-3f60-11e5-8314-005056a87c89             savoirs
#  13  2fae969a-3f60-11e5-8314-005056a87c89             savoirs
#  14  2fae969a-3f60-11e5-8314-005056a87c89             savoirs
#
#                                      data-asset-source data-asset-created-date  \
#  0                                                 NaN                     NaN
#  1   https://media.radiofrance-podcast.net/podcast0...              1591689600
#  2   https://media.radiofrance-podcast.net/podcast0...              1591603200
#  3   https://media.radiofrance-podcast.net/podcast0...              1591344000
#  4   https://media.radiofrance-podcast.net/podcast0...              1591257600
#  5   https://media.radiofrance-podcast.net/podcast0...              1591171200
#  6   https://media.radiofrance-podcast.net/podcast0...              1591084800
#  7   https://media.radiofrance-podcast.net/podcast0...              1590998400
#  8   https://media.radiofrance-podcast.net/podcast0...              1590739200
#  9   https://media.radiofrance-podcast.net/podcast0...              1590652800
#  10  https://media.radiofrance-podcast.net/podcast0...              1590566400
#  11  https://media.radiofrance-podcast.net/podcast0...              1590480000
#  12  https://media.radiofrance-podcast.net/podcast0...              1590393600
#  13  https://media.radiofrance-podcast.net/podcast0...              1590134400
#  14  https://media.radiofrance-podcast.net/podcast0...              1589961600
#
#     data-clip-type
#  0             NaN
#  1        reecoute
#  2        reecoute
#  3        reecoute
#  4        reecoute
#  5        reecoute
#  6        reecoute
#  7        reecoute
#  8        reecoute
#  9        reecoute
#  10       reecoute
#  11       reecoute
#  12       reecoute
#  13       reecoute
#  14       reecoute
#
#  [15 rows x 21 columns],
#                         class data-btn-type data-network-change  \
#  0   replay-button paused aod           aod
#  1   replay-button paused aod           aod
#  2   replay-button paused aod           aod
#  3   replay-button paused aod           aod
#  4   replay-button paused aod           aod
#  5   replay-button paused aod           aod
#  6   replay-button paused aod           aod
#  7   replay-button paused aod           aod
#  8   replay-button paused aod           aod
#  9   replay-button paused aod           aod
#  10  replay-button paused aod           aod
#  11  replay-button paused aod           aod
#  12  replay-button paused aod           aod
#  13  replay-button paused aod           aod
#  14  replay-button paused aod           aod
#
#                                                  title  \
#  0   Réécouter Philosopher avec Scorsese (2/4) : "R...
#  1   Réécouter Philosopher avec Scorsese (1/4) : "T...
#  2   Réécouter Profession philosophe (26/74) : Mich...
#  3   Réécouter La chambre, enfer ou paradis ? (4/4)...
#  4   Réécouter La chambre, enfer ou paradis ? (3/4)...
#  5   Réécouter La chambre, enfer ou paradis ? (2/4)...
#  6   Réécouter La chambre, enfer ou paradis ? (1/4)...
#  7   Réécouter Profession philosophe (12/74) : Chan...
#  8   Réécouter Quatre malentendus spinozistes (4/4)...
#  9   Réécouter Quatre malentendus spinozistes (3/4)...
#  10  Réécouter Quatre malentendus spinozistes (2/4)...
#  11  Réécouter Quatre malentendus spinozistes (1/4)...
#  12  Réécouter Profession philosophe (25/74) : Mark...
#  13  Réécouter Les philosophes face à la maladie (4...
#  14  Réécouter Les philosophes face à la maladie (3...
#
#                                       data-asset-title  \
#  0   Philosopher avec Scorsese (2/4) : "Raging Bull...
#  1   Philosopher avec Scorsese (1/4) : "Taxi Driver...
#  2   Profession philosophe (26/74) : Michaël Foesse...
#  3   La chambre, enfer ou paradis ? (4/4) : Proust,...
#  4   La chambre, enfer ou paradis ? (3/4) : Sartre,...
#  5   La chambre, enfer ou paradis ? (2/4) : Virgini...
#  6   La chambre, enfer ou paradis ? (1/4) : Pascal,...
#  7   Profession philosophe (12/74) : Chantal Jaquet...
#  8   Quatre malentendus spinozistes (4/4) : "L’homm...
#  9   Quatre malentendus spinozistes (3/4) : "La béa...
#  10  Quatre malentendus spinozistes (2/4) : "La ver...
#  11  Quatre malentendus spinozistes (1/4) : "La lib...
#  12  Profession philosophe (25/74) : Mark Alizart, ...
#  13  Les philosophes face à la maladie (4/4) : La d...
#  14  Les philosophes face à la maladie (3/4) : Moli...
#
#                data-asset-surtitle         aria-label  \
#  0   Les Chemins de la philosophie  Lecture du replay
#  1   Les Chemins de la philosophie  Lecture du replay
#  2   Les Chemins de la philosophie  Lecture du replay
#  3   Les Chemins de la philosophie  Lecture du replay
#  4   Les Chemins de la philosophie  Lecture du replay
#  5   Les Chemins de la philosophie  Lecture du replay
#  6   Les Chemins de la philosophie  Lecture du replay
#  7   Les Chemins de la philosophie  Lecture du replay
#  8   Les Chemins de la philosophie  Lecture du replay
#  9   Les Chemins de la philosophie  Lecture du replay
#  10  Les Chemins de la philosophie  Lecture du replay
#  11  Les Chemins de la philosophie  Lecture du replay
#  12  Les Chemins de la philosophie  Lecture du replay
#  13  Les Chemins de la philosophie  Lecture du replay
#  14  Les Chemins de la philosophie  Lecture du replay
#
#                                      data-asset-source data-asset-created-date  \
#  0   https://media.radiofrance-podcast.net/podcast0...              1589875200
#  1   https://media.radiofrance-podcast.net/podcast0...              1589788800
#  2   https://media.radiofrance-podcast.net/podcast0...              1589529600
#  3   https://media.radiofrance-podcast.net/podcast0...              1589443200
#  4   https://media.radiofrance-podcast.net/podcast0...              1589356800
#  5   https://media.radiofrance-podcast.net/podcast0...              1589270400
#  6   https://media.radiofrance-podcast.net/podcast0...              1589184000
#  7   https://media.radiofrance-podcast.net/podcast0...              1588924800
#  8   https://media.radiofrance-podcast.net/podcast0...              1588838400
#  9   https://media.radiofrance-podcast.net/podcast0...              1588752000
#  10  https://media.radiofrance-podcast.net/podcast0...              1588665600
#  11  https://media.radiofrance-podcast.net/podcast0...              1588579200
#  12  https://media.radiofrance-podcast.net/podcast0...              1588320000
#  13  https://media.radiofrance-podcast.net/podcast0...              1588233600
#  14  https://media.radiofrance-podcast.net/podcast0...              1588147200
#
#     data-clip-type data-duration                         data-media-id  \
#  0        reecoute          3538  ff12f484-1407-4705-b084-9251ecc0ce7d
#  1        reecoute          3535  6870df04-e377-4aae-8775-32c7b9d2e109
#  2                         7c2c63ed  065cb521-feef-4afe-be61-be70c0a7cb9f
#  3                         dfb7982b  1fea6769-9925-4293-99b4-6cbe2cdd02c1
#  4                         d5c3f095  a129476b-d260-4f4f-8db5-8fffec3092b5
#  5                         4340846e  61852c7e-967e-4d14-8c2f-b6d705f54cfc
#  6                         543a8011  c6cab782-4472-474e-982e-fc68a5794906
#  7                         b04d503e  2c787632-90b2-4b22-824b-164eb324d4a1
#  8                         05d7cce6  8ff9eca8-8a4f-450d-8f72-a1abceab5773
#  9                         9a9e1193  d3c143d8-613c-440e-9680-5eda30a0715b
#  10                        3dde50e7  278d025c-8cae-4f6d-970f-2b686afa4137
#  11                        1888dfb6  e01507b6-b822-4a75-92c9-1eb574530ef7
#  12                        3dd3436e  632b2557-8772-43ca-a694-4680c18b4978
#  13                        0afed6fa  7b95d019-2a8e-47c1-bd65-8c3af0c7b689
#  14                        2c562c46  9c021737-e8d7-4e67-91f5-f84900a8105b
#
#                           data-concept-id data-universe-title
#  0   2fae969a-3f60-11e5-8314-005056a87c89             savoirs
#  1   2fae969a-3f60-11e5-8314-005056a87c89             savoirs
#  2   2fae969a-3f60-11e5-8314-005056a87c89             savoirs
#  3   2fae969a-3f60-11e5-8314-005056a87c89             savoirs
#  4   2fae969a-3f60-11e5-8314-005056a87c89             savoirs
#  5   2fae969a-3f60-11e5-8314-005056a87c89             savoirs
#  6   2fae969a-3f60-11e5-8314-005056a87c89             savoirs
#  7   2fae969a-3f60-11e5-8314-005056a87c89             savoirs
#  8   2fae969a-3f60-11e5-8314-005056a87c89             savoirs
#  9   2fae969a-3f60-11e5-8314-005056a87c89             savoirs
#  10  2fae969a-3f60-11e5-8314-005056a87c89             savoirs
#  11  2fae969a-3f60-11e5-8314-005056a87c89             savoirs
#  12  2fae969a-3f60-11e5-8314-005056a87c89             savoirs
#  13  2fae969a-3f60-11e5-8314-005056a87c89             savoirs
#  14  2fae969a-3f60-11e5-8314-005056a87c89             savoirs  ]

# %%
dt_lista[0]['data-asset-source'].values
# Out:
# array([nan,
#        'https://media.radiofrance-podcast.net/podcast09/10467-09.06.2020-ITEMA_22357362-0-1779455909.mp3',
#        'https://media.radiofrance-podcast.net/podcast09/10467-08.06.2020-ITEMA_22356504-0-1779455909.mp3',
#        'https://media.radiofrance-podcast.net/podcast09/10467-05.06.2020-ITEMA_22354732-0-1779455909.mp3',
#        'https://media.radiofrance-podcast.net/podcast09/10467-04.06.2020-ITEMA_22353885-1-1779455909.mp3',
#        'https://media.radiofrance-podcast.net/podcast09/18755-03.06.2020-ITEMA_22353111-1-1779455909.mp3',
#        'https://media.radiofrance-podcast.net/podcast09/10467-02.06.2020-ITEMA_22352273-0-1779455909.mp3',
#        'https://media.radiofrance-podcast.net/podcast09/10467-01.06.2020-ITEMA_22351506-1-1779455909.mp3',
#        'https://media.radiofrance-podcast.net/podcast09/10467-29.05.2020-ITEMA_22349859-0-1779455909.mp3',
#        'https://media.radiofrance-podcast.net/podcast09/10467-28.05.2020-ITEMA_22349067-0-1779455909.mp3',
#        'https://media.radiofrance-podcast.net/podcast09/10467-27.05.2020-ITEMA_22348297-1-1779455909.mp3',
#        'https://media.radiofrance-podcast.net/podcast09/18755-26.05.2020-ITEMA_22347523-1-1779455909.mp3',
#        'https://media.radiofrance-podcast.net/podcast09/18755-25.05.2020-ITEMA_22346743-1-1779455909.mp3',
#        'https://media.radiofrance-podcast.net/podcast09/18755-22.05.2020-ITEMA_22345143-1-1779455909.mp3',
#        'https://media.radiofrance-podcast.net/podcast09/10467-20.05.2020-ITEMA_22343582-1-1779455909.mp3'],
#       dtype=object)
